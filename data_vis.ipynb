# %%
data_root = "/home/lhxk/workspace/repos/streamIGGT/IGGT_reproduce/data_debug/scene_000_extracted/frames/camview/camera_0/camview_0_0_0001_0.npz"

import numpy as np

for i in range(1, 3):
    data_path = f"/home/lhxk/workspace/repos/streamIGGT/IGGT_reproduce/data_debug/scene_000_extracted/frames/camview/camera_0/camview_{i}_0_0001_0.npz"
    data = np.load(data_path)

    print(f"Keys in the NPZ file for camview_{i}_0_0001_0.npz:", list(data.keys()))
    for key in data.keys():
        print(f"{key}: shape {data[key].shape}, dtype {data[key].dtype}")
        print(data['K'])
        print(data['T'])
        print(data['HW'])
